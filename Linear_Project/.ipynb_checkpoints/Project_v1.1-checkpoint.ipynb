# %% [markdown]
# ##### Import Library

# %%
# for numerical calculation
import numpy as np
# for DataFrame related problem
import pandas as pd

# for visualation

import matplotlib.pyplot as plt
import seaborn as sns

# import Linear Model
from sklearn.linear_model import LinearRegression

#import library for splitting of training datasets and testing datasets
from sklearn.model_selection import train_test_split

# Evolution metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# for calculate of vif
from statsmodels.stats.outliers_influence import variance_inflation_factor

# for model
import pickle

# for data store
import json

# for ignor warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### 1) Problem Statement

# %%
# To predict medical insurance price based on independent varibles.

# %% [markdown]
# ##### 2) Data Gathering

# %%
df = pd.read_csv("medical_insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ##### 3) EDA/ Data validation/ Data Quality Check

# %%
df.isna().sum() # sum of missing value
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.isna().mean()*100 # percentage of missing value
# Out:
# age         0.0
# sex         0.0
# bmi         0.0
# children    0.0
# smoker      0.0
# region      0.0
# charges     0.0
# dtype: float64

# %%
df.describe() # it return numerical stats means it return min, max, count, std, mean, 25, 50, 75
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info() # it will return count of non null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.pairplot(df)

# %%
sns.kdeplot(df[['age','bmi','children']],fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# calculate vif --- vif is used for only numerical data

# %%
sns.kdeplot(df["children"])
# Out:
# <Axes: xlabel='children', ylabel='Density'>

# %%
sns.boxplot(df["children"])
# Out:
# <Axes: >

# %%
df1 = df.drop(["charges","sex","smoker","region"],axis=1) # drop the charges column for calculate vif
vif = pd.DataFrame()
vif["Feature"] = df1.columns
vif["vif_factor"] = [variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif
# Out:
#     Feature  vif_factor
# 0       age    7.536550
# 1       bmi    7.846515
# 2  children    1.796637

# %%
# column wise

# %%
df["age"].unique(),df["age"].nunique()
# Out:
# (array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#         59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#         20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39], dtype=int64),
#  47)

# %%
sns.kdeplot(df["age"])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(df["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.displot(df["age"])

# %%
df.head(1)
# Out:
#    age     sex   bmi  children smoker     region    charges
# 0   19  female  27.9         0    yes  southwest  16884.924

# %%
df["sex"].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df["sex"].value_counts(normalize=True) # it return percentage of categories
# Out:
# male      0.505232
# female    0.494768
# Name: sex, dtype: float64

# %%
df["smoker"].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df["smoker"].value_counts(normalize=True)
# Out:
# no     0.795217
# yes    0.204783
# Name: smoker, dtype: float64

# %%
df["region"].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# ##### 4) Feature Engineering

# %%
# do treatment on missing if it has >>> fillna()
#remane
# encoding

# %%
df.rename(columns={"sex":"gender"},inplace=True)
df.head(1)
# Out:
#    age  gender   bmi  children smoker     region    charges
# 0   19  female  27.9         0    yes  southwest  16884.924

# %%
df.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
## replace

# %%
df['gender'].value_counts()
# Out:
# male      676
# female    662
# Name: gender, dtype: int64

# %%
df["gender"].replace({"male":0,"female":1},inplace=True)

# %%
df["smoker"].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df["smoker"].replace({"yes":0,"no":1},inplace=True)

# %%
df.head()
# Out:
#    age  gender     bmi  children  smoker     region      charges
# 0   19       1  27.900         0       0  southwest  16884.92400
# 1   18       0  33.770         1       1  southeast   1725.55230
# 2   28       0  33.000         3       1  southeast   4449.46200
# 3   33       0  22.705         0       1  northwest  21984.47061
# 4   32       0  28.880         0       1  northwest   3866.85520

# %%
df = pd.get_dummies(df,columns=["region"])
df.head()
# Out:
#    age  gender     bmi  children  smoker      charges  region_northeast  \
# 0   19       1  27.900         0       0  16884.92400                 0
# 1   18       0  33.770         1       1   1725.55230                 0
# 2   28       0  33.000         3       1   4449.46200                 0
# 3   33       0  22.705         0       1  21984.47061                 0
# 4   32       0  28.880         0       1   3866.85520                 0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %% [markdown]
# ##### 5) Feature selection

# %%
df.corr() # only used for numerical column not for categorical
# Out:
#                        age    gender       bmi  children    smoker   charges  \
# age               1.000000  0.020856  0.109272  0.042469  0.025019  0.299008
# gender            0.020856  1.000000 -0.046371 -0.017163  0.076185 -0.057292
# bmi               0.109272 -0.046371  1.000000  0.012759 -0.003750  0.198341
# children          0.042469 -0.017163  0.012759  1.000000 -0.007673  0.067998
# smoker            0.025019  0.076185 -0.003750 -0.007673  1.000000 -0.787251
# charges           0.299008 -0.057292  0.198341  0.067998 -0.787251  1.000000
# region_northeast  0.002475  0.002425 -0.138156 -0.022808 -0.002811  0.006349
# region_northwest -0.000407  0.011156 -0.135996  0.024806  0.036945 -0.039905
# region_southeast -0.011642 -0.017117  0.270025 -0.023066 -0.068498  0.073982
# region_southwest  0.010016  0.004184 -0.006205  0.021914  0.036945 -0.043210
#
#                   region_northeast  region_northwest  region_southeast  \
# ...

# %%
df1 = df.drop(["charges","gender","smoker","region_northeast","region_northwest","region_southeast","region_southwest"],axis=1) # drop the charges column for calculate vif
vif = pd.DataFrame()
vif["Feature"] = df1.columns
vif["vif_factor"] = [variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif
# Out:
#     Feature  vif_factor
# 0       age    7.536550
# 1       bmi    7.846515
# 2  children    1.796637

# %% [markdown]
# ##### 6) Model selection

# %% [markdown]
# ###### 6.1) data spliting

# %%
x = df.drop(["charges"],axis=1)
y = df["charges"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.80,random_state=40)

# %% [markdown]
# ##### 7) Model Evalution

# %%
lr_model = LinearRegression()
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ##### 7.1) Model testing

# %%
y_pred = lr_model.predict(x_test)

# calculate mse

mse = mean_squared_error(y_test,y_pred)
print("MSE>>>>",mse)

# calculate mae

mae = mean_absolute_error(y_test,y_pred)
print("MAE>>>>",mae)

# calculate rmse

rmse = np.sqrt(mse)
print("RMSE>>>",rmse)

# calculate r2 

r2 = r2_score(y_test,y_pred)
print("R2>>>>",r2)

adj_r2 = 1- (((1-r2)*(x_test.shape[0]-1))/(x_test.shape[0]-x_test.shape[1]-1))
print("adj_r2>>>>>",adj_r2)
# Out:
# MSE>>>> 37261207.6918935
# MAE>>>> 4606.8994384125535
# RMSE>>> 6104.195908708492
# R2>>>> 0.7383366509155701
# adj_r2>>>>> 0.7361170749101413

# %% [markdown]
# ###### Model training

# %%
y_pred = lr_model.predict(x_train)

# calculate mse

mse = mean_squared_error(y_train,y_pred)
print("MSE>>>>",mse)

# calculate mae

mae = mean_absolute_error(y_train,y_pred)
print("MAE>>>>",mae)

# calculate rmse

rmse = np.sqrt(mse)
print("RMSE>>>",rmse)

# calculate r2 

r2 = r2_score(y_train,y_pred)
print("R2>>>>",r2)

adj_r2 = 1- (((1-r2)*(x_train.shape[0]-1))/(x_train.shape[0]-x_train.shape[1]-1))
print("adj_r2>>>>>",adj_r2)
# Out:
# MSE>>>> 43098634.76265413
# MAE>>>> 4813.4793057128545
# RMSE>>> 6564.955046506726
# R2>>>> 0.7332576680377806
# adj_r2>>>>> 0.7239164968795706

# %%
df.head(1)
# Out:
#    age  gender   bmi  children  smoker    charges  region_northeast  \
# 0   19       1  27.9         0       0  16884.924                 0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1

# %%
project_data = {"gender":{"female":1,"male":0},
               "smoker":{"yes":1,"no":0},
               "coulmns":x.columns}
project_data
# Out:
# {'gender': {'female': 1, 'male': 0},
#  'smoker': {'yes': 1, 'no': 0},
#  'coulmns': Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region_northeast',
#         'region_northwest', 'region_southeast', 'region_southwest'],
#        dtype='object')}

# %%
with open("Linear_model","wb") as file:
    pickle.dump(lr_model,file)

# %% [markdown]
# ##### 8) Deployment

# %% [markdown]
# ###### User Input

# %%
df.iloc[1,:] # return 1st rows of dataframe
# Out:
# age                   18.0000
# gender                 0.0000
# bmi                   33.7700
# children               1.0000
# smoker                 1.0000
# charges             1725.5523
# region_northeast       0.0000
# region_northwest       0.0000
# region_southeast       1.0000
# region_southwest       0.0000
# Name: 1, dtype: float64

# %%
age = 18.0000
gender = "male"
bmi = 33.7700
children = 1.0000
smoker = "yes"
region = "southeast"

# %%
x.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region_northeast',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
columns_names = x.columns
test_array = np.zeros(len(columns_names)) # x.shape[1]
test_array[0] = age
test_array[1] = project_data["gender"]["male"]
test_array[2] = bmi
test_array[3] = children
test_array[4] = project_data["smoker"]["yes"]
region1 = "region_" + region
region_index = np.where(columns_names == region1)
test_array[region_index] = 1
test_array
# region_index
# Out:
# array([18.  ,  0.  , 33.77,  1.  ,  1.  ,  0.  ,  0.  ,  1.  ,  0.  ])

# %%
insurance_price_prediction = np.around(lr_model.predict([test_array])[0],2)
print("Charges is ",insurance_price_prediction)
# Out:
# Charges is  3663.86
